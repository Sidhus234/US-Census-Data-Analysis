# %% [markdown]
# # <span style="color:Maroon">Data Preparation - Part 3

# %% [markdown]
# <span style="color:Green">__Overview:__ Create dataset at county level. The columns store the data for census population levels of the county

# %%
# Import Required libraries
import pandas as pd
import numpy as np
import os as os

# %%
os.chdir("..")
cwd = os.getcwd()
other_data = "\\Data\\other data"
os.chdir(f'{cwd}{other_data}')

# %%
data = pd.read_csv("co-est2013-alldata.csv",encoding = "ISO-8859-1")

# %%
data.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RNATURALINC2013  \
# 0        4779736            4779758          4785570  ...         2.059008
# 1          54571              54571            54613  ...         2.388902
# 2         182265             182265           183223  ...         1.843533
# 3          27457              27457            27341  ...         0.073654
# 4          22915              22919            22883  ...         1.151105
#
#    RINTERNATIONALMIG2011  RINTERNATIONALMIG2012  RINTERNATIONALMIG2013  \
# ...

# %%
data["FIPS"] = np.where(data["COUNTY"]==0,data["STATE"],data["STATE"]*1000+data["COUNTY"])

# %%
data.head()
data = data.drop(["SUMLEV","REGION","DIVISION","STATE","COUNTY","CTYNAME","STNAME"],axis=1)
data = data.set_index("FIPS")
data.to_csv(f"{cwd}\\Data\\Model data\\County_population_data.csv")
